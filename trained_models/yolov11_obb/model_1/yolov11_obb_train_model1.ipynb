# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolo11n-obb.yaml")  # build a new model from YAML
model = YOLO("yolo11n-obb.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n-obb.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data=r"C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\data\dataset_1\model_1_train.yaml", 
                      epochs=100, imgsz=768, patience = 75)
# Out:
# Transferred 499/541 items from pretrained weights
# Ultralytics 8.3.240  Python-3.13.11 torch-2.9.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\data\dataset_4\training_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=768, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-obb.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=75, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11n.pt, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\trained_models\yolov11_obb\model_4\runs\obb\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\engine\trainer.py:649, in BaseTrainer.get_dataset(self)
#     643 elif str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     644     "detect",
#     645     "segment",
#     646     "pose",
#     647     "obb",
#     648 }:
# --> 649     data = check_det_dataset(self.args.data)
#     650     if "yaml_file" in data:
#
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\data\utils.py:462, in check_det_dataset(dataset, autodownload)
#     461     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 462     raise FileNotFoundError(m)
#     463 t = time.time()
#
# FileNotFoundError: Dataset 'C://Users/victa/OneDrive/Documents/GitHub/2025_Hackathon/data/dataset_4/training_data.yaml' images not found, missing path 'C:\home\jed\git\2025_Hackathon\data\dataset_4\images\validation'
# Note dataset download directory is 'C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\datasets'. You can update this in 'C:\Users\victa\AppData\Roaming\Ultralytics\settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 9
#       6 model = YOLO("yolo11n-obb.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
#       8 # Train the model
# ----> 9 results = model.train(data=r"C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\data\dataset_4\training_data.yaml",
#      10                       epochs=100, imgsz=768, patience = 75)
#
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\engine\model.py:768, in Model.train(self, trainer, **kwargs)
#     765 if args.get("resume"):
#     766     args["resume"] = self.ckpt_path
# --> 768 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     769 if not args.get("resume"):  # manually set model only if not resuming
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\models\yolo\obb\train.py:48, in OBBTrainer.__init__(self, cfg, overrides, _callbacks)
#      46     overrides = {}
#      47 overrides["task"] = "obb"
# ---> 48 super().__init__(cfg, overrides, _callbacks)
#
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\models\yolo\detect\train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection models.
#      57
#      58     Args:
#    (...)     61         _callbacks (list, optional): List of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\engine\trainer.py:163, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     161 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     162 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 163     self.data = self.get_dataset()
#     165 self.ema = None
#     167 # Optimization utils init
#
# File c:\Users\victa\anaconda3\envs\defect_detector\Lib\site-packages\ultralytics\engine\trainer.py:653, in BaseTrainer.get_dataset(self)
#     651             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     652 except Exception as e:
# --> 653     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     654 if self.args.single_cls:
#     655     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'C://Users/victa/OneDrive/Documents/GitHub/2025_Hackathon/data/dataset_4/training_data.yaml' error  Dataset 'C://Users/victa/OneDrive/Documents/GitHub/2025_Hackathon/data/dataset_4/training_data.yaml' images not found, missing path 'C:\home\jed\git\2025_Hackathon\data\dataset_4\images\validation'
# Note dataset download directory is 'C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\datasets'. You can update this in 'C:\Users\victa\AppData\Roaming\Ultralytics\settings.json'
