# %%
from ultralytics import YOLO
from pathlib import Path
import os

# %%
# Load a model
model_path = Path(os.getcwd()) / "trained_models" / "yolov11_obb" / "model_1" / "weights" / "best.pt"
model = YOLO(model_path)
# model = YOLO(r"C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\trained_models\yolov11_obb\model_1\weights\best.pt")  # load a pretrained model (recommended for training)

# real_im = r"C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\CdTe_Training_Image_photoshop_fake_defects_TP.png"
real_im = Path(os.getcwd()) / "CdTe_Training_Image_photoshop_fake_defects_TP.png"

# Train the model
results = model(real_im, show=True)
# Out:
# image 1/1 /home/jed/git/2025_Hackathon/CdTe_Training_Image_photoshop_fake_defects_TP.png: 768x768 3 grain_boundarys, 4 vacancys, 1 interstitial, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 768)
